# %%
import matplotlib.pyplot as plt
import numpy as np


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data

#Dictionary to store triggered time
trigger_time = {
    '7': [-7.6875, -3.3476, -2.6469998, -2.0161, -1.0834, -0.52169997],
    '19': [-1.0781, -0.3664],
    '40':[-25.605999, -20.8611, -11.0869, -6.2176, -1.2555, -0.53459996], 
    '42':[-13.0497, -0.5937], 
    '43':[-6.9467998, -0.6522], 
    '57':[-0.5082]}

#Reached previous quench's maximum current when?
reached_max = {
    '7': [-6.15],
    '19': [-2.15],
    '40':[-1.95], 
    '42':[-0.5], 
    '43':[-1.15], 
    '57':[-1.55]}

started_training =  {
    '7': [-50],
    '19': [-50],
    '40':[-50], 
    '42':[-50], 
    '43':[-50], 
    '57':[-50]}

ramp_names = list(trigger_time.keys())
y_pos = np.arange(len(ramp_names))

first_label = True
first_label_1 = True

#Loop through each ramp to plot trigger time
for i in range(len(ramp_names)):
    
    #Plot the time reached max current time
    if reached_max[ramp_names[i]]:
        if first_label:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black', label = 'Reached previous max current')
            first_label = False
        else:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black')
            
    #Get the trigger time for that ramp
    trigger_ramp = trigger_time[ramp_names[i]] 
    if trigger_ramp:
        plt.plot(trigger_ramp, [y_pos[i]]*len(trigger_ramp), '-o')
        
    #Plot the time started training
    if started_training[ramp_names[i]]:
        if first_label_1:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red', label = 'Training started')
            first_label_1 = False
        else:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red')
    
    
#ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ramp_names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('Ramp number')
ax.set_xlabel('Time (s)')
ax.set_title('Every trigger time of each ramp (Log10 threshold 1.6)')
plt.legend(loc = 'lower left')
plt.xlim([-25,2])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data

#Dictionary to store triggered time
trigger_time = {
    '1': [-8.10439, -7.29349, -5.9109898, -4.83739, -4.24249, -3.6989899, -3.0147898, -2.43099, -1.6677899, -0.75219, -0.074889995],
    '2': [-28.1337, -25.3406, -23.952099, -23.392, -20.668, -19.4495, -10.3334, -6.6449],
    '3': [-9.6339, -7.6225996, -6.9283, -6.0299997, -5.3178, -4.7251, -3.326, -2.8137999, -1.4969, -0.5563],
    '4': [-6.9467998],
    '5': [-10.373099, -1.8928, -1.2480999, -0.62659997],
    '6': [-3.6125998, -1.8406999, -1.05, -0.0176],
    '7': [-3.3479998, -2.6469998, -2.0161, -1.0834, -0.52169997],
    '8': [-1.8632, -0.1069],
    '10': None,
    '11': [-2.1239, -1.3987, -0.40559998],
    '12':[-9.573999, -8.625899, -8.1044, -7.2935, -6.5983, -5.911, -4.8374, -4.2426, -3.699, -2.9743, -2.431, -1.668, -0.7522, -0.0749],
    '19': [-1.0781, -0.3664],
    '40':[-25.605999, -20.8611, -11.0869, -6.2176, -1.2555, -0.53459996], 
    '42':[-13.0497, -0.5937], 
    '43':[-6.9467998, -0.6522], 
    '57':[-0.5082]}

#Reached previous quench's maximum current when?
reached_max = {
    '1': None,
    '2': -19.7,
    '3': -17,
    '4': -6.3,
    '5': -2.55,
    '6': -2.8,
    '7': -6.15,
    '8': -2.2,
    '10':-2.75,
    '11':-1.95,
    '12':-4.95,
    '19': -2.15,
    '40':-1.95, 
    '42':-0.5, 
    '43':-1.15, 
    '57':-1.55}

started_training =  {
    '1': -200,
    '2': -60,
    '3': -50,
    '4': -50,
    '5': -50,
    '6': -50,
    '7': -50,
    '8': -50,
    '10': -50,
    '11': -50,
    '12': -50,
    '19': [-50],
    '40':[-50], 
    '42':[-50], 
    '43':[-50], 
    '57':[-50]
}

ramp_names = list(trigger_time.keys())
print("Total number of ramps: ", len(ramp_names))
y_pos = np.arange(len(ramp_names))

first_label = True
first_label_1 = True

#Loop through each ramp to plot trigger time
for i in range(len(ramp_names)):
    
    #Plot the time reached max current time
    if reached_max[ramp_names[i]]:
        if first_label:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black', label = 'Reached previous max current')
            first_label = False
        else:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black')
            
    #Get the trigger time for that ramp
    trigger_ramp = trigger_time[ramp_names[i]] 
    if trigger_ramp:
        plt.plot(trigger_ramp, [y_pos[i]]*len(trigger_ramp), '-o')
        
    #Plot the time started training
    if started_training[ramp_names[i]]:
        if first_label_1:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red', label = 'Training started')
            first_label_1 = False
        else:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red')
    
    
#ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ramp_names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('Ramp number')
ax.set_xlabel('Time (s)')
ax.set_title('Every trigger time of dynamic threshold (Log10 threshold 3.0 -> 1.6)')
plt.legend(loc = 'lower left')
plt.xlim([-30,2])

plt.show()
# Out:
# Total number of ramps:  16

# %% [markdown]
# -------

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data

#Dictionary to store triggered time
trigger_time = {
    '1': [-8.10439, -7.29349, -5.9109898, -4.83739, -4.24249, -3.6989899, -3.0147898, -2.43099, -1.6677899, -0.75219, -0.074889995],
    '2': [-28.1337, -25.3406, -23.952099, -23.392, -20.668, -19.4495, -10.3334, -6.6449],
    '3': [-9.6339, -7.6225996, -6.9283, -6.0299997, -5.3178, -4.7251, -3.326, -2.8137999, -1.4969, -0.5563],
    '4': [-6.9467998],
    '5': [-10.373099, -1.8928, -1.2480999, -0.62659997],
    '6': [-3.6125998, -1.8406999, -1.05, -0.0176],
    '7': [-3.3479998, -2.6469998, -2.0161, -1.0834, -0.52169997],
    '8': [-1.8632, -0.1069],
    '10': None,
    '11': [-2.1239, -1.3987, -0.40559998],
    '12':[-9.573999, -8.625899, -8.1044, -7.2935, -6.5983, -5.911, -4.8374, -4.2426, -3.699, -2.9743, -2.431, -1.668, -0.7522, -0.0749]}

#Reached previous quench's maximum current when?
reached_max = {
    '1': None,
    '2': -19.7,
    '3': -17,
    '4': -6.3,
    '5': -2.55,
    '6': -2.8,
    '7': -6.15,
    '8': -2.2,
    '10':-2.75,
    '11':-1.95,
    '12':-4.95}

started_training =  {
    '1': -200,
    '2': -60,
    '3': -50,
    '4': -50,
    '5': -50,
    '6': -50,
    '7': -50,
    '8': -50,
    '10': -50,
    '11': -50,
    '12': -50
}

ramp_names = list(trigger_time.keys())
y_pos = np.arange(len(ramp_names))

first_label = True
first_label_1 = True

#Loop through each ramp to plot trigger time
for i in range(len(ramp_names)):
    
    #Plot the time reached max current time
    if reached_max[ramp_names[i]]:
        if first_label:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black', label = 'Reached previous max current')
            first_label = False
        else:
            plt.scatter(reached_max[ramp_names[i]], y_pos[i], marker = 's', color = 'black')
            
    #Get the trigger time for that ramp
    trigger_ramp = trigger_time[ramp_names[i]] 
    if trigger_ramp:
        plt.plot(trigger_ramp, [y_pos[i]]*len(trigger_ramp), '-o')
        
    #Plot the time started training
    if started_training[ramp_names[i]]:
        if first_label_1:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red', label = 'Training started')
            first_label_1 = False
        else:
            plt.scatter(started_training[ramp_names[i]], y_pos[i], marker = '2', color = 'red')
    
    
#ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(ramp_names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('Ramp number')
ax.set_xlabel('Time (s)')
ax.set_title('Every trigger time of dynamic threshold (Log10 threshold 3.0 -> 1.6)')
plt.legend(loc = 'lower left')
plt.xlim([-30,2])

plt.show()

# %% [markdown]
# ----------

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data

#Dictionary to store triggered time
anomaly_coord = {
    '1': [[3.6244817, 41.105335], [7.25784, 62.36469], [2.2284782, 11.505366], [7.755621, 50.634464], [19.333372, 226.08217], [2.6627264, 11.955329], [4.8397064, 29.239836], [40.838367, 365.57687], [15.268868, 172.1873], [111.76777, 1122.3679], [2.5351248, 18.352226]],
    '2': [[5.0710354, 5.000244], [2.9419599, 2.1211402], [3.3076043, 5.499067], [11.083316, 6.857567], [2.348038, 2.3726149], [2.4154637, 2.951368], [3.4048023, 1.3239843], [2.9809895, 1.822134], [6.0562043, 4.289018]],
    '3': [[1.3319924, -0.9996022], [0.7260706, -0.9426908], [2.3027265, -0.9955489], [2.1639276, -0.9999838], [1.865993, -0.9998456], [1.6875012, -0.9999959], [1.5322527, -0.9999634], [0.72433126, -0.9700518], [1.8009458, -0.99975306], [1.7415011, -0.99999946], [0.8403848, -0.9944623], [4.6795187, -1.0], [1.8938696, -0.9996593]],
    '4': [[8.044549, 28.527817]],
    '5': [[-0.9632637, 1.9758841], [-0.9410857, 2.1789258], [-0.9989639, 5.624843], [-1.0, 16.465193], [-0.9984582, 5.906258], [-0.8935778, 1.6547841]],
    '6': [[10.152525, 15.655844], [7.670228, 12.83584], [7.3321314, 7.711208], [3.903199, 3.2333188]],
    '7': [[0.5828829, 3.7593672], [0.33524334, 2.805068], [1.1351721, 12.009794], [-0.56969553, 32.841015], [0.67500085, 20.04919], [3.3927972, 35.74431], [1.1717228, 9.146957]],
    '8': [[54.543404, 16.995281], [39.704525, 11.134226]],
    '10': None,
    '11':[[-0.63631356, 6.976051], [-0.7660404, 7.8774495], [-0.9545901, 11.157507]],
    '12':[[-0.5536701, 9.007492], [5.2557487, 41.821766], [6.853834, 66.270744], [0.40881938, 11.077302], [3.98977, 53.74483], [31.26844, 251.55766], [0.18100636, 11.695562], [1.9241408, 30.035614], [42.969944, 417.18042], [23.131325, 189.57088], [146.86552, 1311.3181], [1.4913352, 17.978231]],
    '19':[[0.82209724, 1.5918052], [-0.011896133, 2.0467482]],
    '40':[[-0.53607315, 4.942854], [-0.5243323, 4.406672], [-0.53284323, 7.692346], [-0.9862183, 16.517235]],
    '42':[[-0.14276153, 2.9882479], [-0.383148, 1.7249856]],
    '43': [[-0.9500273, 20.936474], [0.4456206, 4.504785]],
    '57': [[3.9174123, 1.8267924]]}

ramp_names = list(anomaly_coord.keys())

print(ramp_names)
#Loop through each ramp to plot
for i in range(len(ramp_names)):
    
    if anomaly_coord[ramp_names[i]] is not None:
        x_coord = [x[0] for x in anomaly_coord[ramp_names[i]]]
        y_coord = [y[1] for y in anomaly_coord[ramp_names[i]]]
    
        plt.scatter(x_coord , y_coord, label = ramp_names[i])
    
    
#ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_title('Latent space of anomalies')
plt.legend(title = "Ramp number", loc = 'best', ncol=2)
plt.xlim([-5,20])
plt.ylim([-5,200])

plt.show()
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '10', '11', '12', '19', '40', '42', '43', '57']
